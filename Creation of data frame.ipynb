# %%
import os

# %%
import pandas as pd

# %%
p="E:\Python"

# %%
os.chdir(p)

# %%
os.getcwd()
# Out:
# 'E:\\Python'

# %%
df=pd.read_csv('Admit.csv')

# %%
df
# Out:
#      GRE  TOEFL  Univ_Rating  SOP  LOR  CGPA  Research  Admit
# 0    337    118            4  4.5  4.5  9.65         1      1
# 1    324    107            4  4.0  4.5  8.87         1      1
# 2    316    104            3  3.0  3.5  8.00         1      1
# 3    322    110            3  3.5  2.5  8.67         1      1
# 4    314    103            2  2.0  3.0  8.21         0      0
# ..   ...    ...          ...  ...  ...   ...       ...    ...
# 395  324    110            3  3.5  3.5  9.04         1      1
# 396  325    107            3  3.0  3.5  9.11         1      1
# 397  330    116            4  5.0  4.5  9.45         1      1
# 398  312    103            3  3.5  4.0  8.78         0      0
# 399  333    117            4  5.0  4.0  9.66         1      1
#
# [400 rows x 8 columns]

# %%
df1=pd.read_csv('Admit_missing.csv')

# %% [markdown]
# # Creation of data frame

# %%
Std_profile=pd.DataFrame({'NAME':['Sandy','Kamal','Bala','Vinu','Sivagami'],
                          'age':[24,21,17,27,50],'Gender':['Female','Male','Male','Male','Female']},
                         index=['Std1','Std2','Std3','Std4','Std5'])

# %%
Std_profile
# Out:
#           NAME  age  Gender
# Std1     Sandy   24  Female
# Std2     Kamal   21    Male
# Std3      Bala   17    Male
# Std4      Vinu   27    Male
# Std5  Sivagami   50  Female

# %%
EX=pd.DataFrame({'COL1':['a','d','g'],'COL2':['b','e','h'],'COL3':['c','f','i']},index=['row1','row2','row3'])

# %%
EX
# Out:
#      COL1 COL2 COL3
# row1    a    b    c
# row2    d    e    f
# row3    g    h    i

# %%
COL4=[1,2,3]

# %%
EX['COL4']=COL4

# %%
EX
# Out:
#      COL1 COL2 COL3  COL4
# row1    a    b    c     1
# row2    d    e    f     2
# row3    g    h    i     3

# %%
EX.iloc[1,1]=5

# %%
EX
# Out:
#      COL1 COL2 COL3  COL4
# row1    a    b    c     1
# row2    d    5    f     2
# row3    g    h    i     3

# %%
EX=EX.drop('COL2',axis=1)

# %%
EX
# Out:
#      COL1 COL3  COL4
# row1    a    c     1
# row2    d    f     2
# row3    g    i     3

# %%
EX=EX.drop('row1',axis=0)

# %%
EX
# Out:
#      COL1 COL3  COL4
# row2    d    f     2
# row3    g    i     3

# %%
type(EX)
# Out:
# pandas.core.frame.DataFrame

# %%
EX.shape
# Out:
# (2, 3)

# %%
EX.shape[0]
# Out:
# 2

# %%
EX.shape[1]
# Out:
# 3

# %%
EX
# Out:
#      COL1 COL3  COL4
# row2    d    f     2
# row3    g    i     3

# %%
EX.loc[:,['COL1','COL3']]
# Out:
#      COL1 COL3
# row2    d    f
# row3    g    i

# %%
EX.loc[['row2'],['COL1']]
# Out:
#      COL1
# row2    d

# %%
df.groupby('Admit')['Admit'].count()
# Out:
# Admit
# 0    165
# 1    235
# Name: Admit, dtype: int64

# %%
df.groupby('Research')['Research'].count()/df.Research.count()*100
# Out:
# Research
# 0    45.25
# 1    54.75
# Name: Research, dtype: float64

# %%
EX
# Out:
#      COL1 COL3  COL4
# row2    d    f     2
# row3    g    i     3

# %%
EX=EX.rename(columns={'COL1':'C1','COL3':'C2','COL4':'C3'})

# %%
EX
# Out:
#      C1 C2  C3
# row2  d  f   2
# row3  g  i   3

# %%
EX=EX.rename(index={'row2':'R2','row3':'R3'})

# %%
EX
# Out:
#    C1 C2  C3
# R2  d  f   2
# R3  g  i   3

# %%
R4=pd.Series(data={'C1':'k','C2':'m','C3':1},name='R4')

# %%
R4
# Out:
# C1    k
# C2    m
# C3    1
# Name: R4, dtype: object

# %%
EX=EX.append(R4)

# %%
EX
# Out:
#    C1 C2   C3
# R2  d  f  2.0
# R3  g  i  3.0
# R4  k  m  1.0

# %%
df1=pd.DataFrame({'A':['a0','a1','a2','a3','a4'],'B':['b0','b1','b2','b3','b4'],'C':['c0','c1','c2','c3','c4'],
                 'D':['d0','d1','d2','d3','d4']})

# %%
df2=pd.DataFrame({'A':['a5','a6','a7','a8','a9'],'B':['b5','b6','b7','b8','b9'],'C':['c5','c6','c7','c8','c9'],
                 'D':['d5','d6','d7','d8','d9']})

# %%
df3=pd.DataFrame({'A':['a10','a11','a12','a13','a14'],'B':['b10','b11','b12','b13','b14'],'C':['c10','c11','c12','c13','c14'],
                 'D':['d10','d11','d12','d13','d14']})

# %%
df1
# Out:
#     A   B   C   D
# 0  a0  b0  c0  d0
# 1  a1  b1  c1  d1
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3
# 4  a4  b4  c4  d4

# %%
df2
# Out:
#     A   B   C   D
# 0  a5  b5  c5  d5
# 1  a6  b6  c6  d6
# 2  a7  b7  c7  d7
# 3  a8  b8  c8  d8
# 4  a9  b9  c9  d9

# %%
df3
# Out:
#      A    B    C    D
# 0  a10  b10  c10  d10
# 1  a11  b11  c11  d11
# 2  a12  b12  c12  d12
# 3  a13  b13  c13  d13
# 4  a14  b14  c14  d14

# %%
df4=pd.concat([df1,df2,df3])

# %%
df4
# Out:
#      A    B    C    D
# 0   a0   b0   c0   d0
# 1   a1   b1   c1   d1
# 2   a2   b2   c2   d2
# 3   a3   b3   c3   d3
# 4   a4   b4   c4   d4
# 0   a5   b5   c5   d5
# 1   a6   b6   c6   d6
# 2   a7   b7   c7   d7
# 3   a8   b8   c8   d8
# 4   a9   b9   c9   d9
# 0  a10  b10  c10  d10
# 1  a11  b11  c11  d11
# 2  a12  b12  c12  d12
# 3  a13  b13  c13  d13
# 4  a14  b14  c14  d14

# %%
df4=pd.concat([df1,df2,df3],ignore_index=True)

# %%
df4
# Out:
#       A    B    C    D
# 0    a0   b0   c0   d0
# 1    a1   b1   c1   d1
# 2    a2   b2   c2   d2
# 3    a3   b3   c3   d3
# 4    a4   b4   c4   d4
# 5    a5   b5   c5   d5
# 6    a6   b6   c6   d6
# 7    a7   b7   c7   d7
# 8    a8   b8   c8   d8
# 9    a9   b9   c9   d9
# 10  a10  b10  c10  d10
# 11  a11  b11  c11  d11
# 12  a12  b12  c12  d12
# 13  a13  b13  c13  d13
# 14  a14  b14  c14  d14

# %%
df5=pd.concat([df1,df2,df3],axis=1)

# %%
df5
# Out:
#     A   B   C   D   A   B   C   D    A    B    C    D
# 0  a0  b0  c0  d0  a5  b5  c5  d5  a10  b10  c10  d10
# 1  a1  b1  c1  d1  a6  b6  c6  d6  a11  b11  c11  d11
# 2  a2  b2  c2  d2  a7  b7  c7  d7  a12  b12  c12  d12
# 3  a3  b3  c3  d3  a8  b8  c8  d8  a13  b13  c13  d13
# 4  a4  b4  c4  d4  a9  b9  c9  d9  a14  b14  c14  d14

# %%
import numpy as np

# %%
np.count_nonzero(df1['GRE'].isnull())
# Out:
# 4

# %%
df1.isna().sum()
# Out:
# GRE            4
# TOEFL          0
# Univ_Rating    6
# SOP            5
# LOR            0
# CGPA           9
# Research       1
# Admit          0
# dtype: int64

# %%
df6=df1.fillna(method='ffill')

# %%
df6
# Out:
#        GRE  TOEFL  Univ_Rating  SOP  LOR  CGPA  Research  Admit
# 0    337.0    118          4.0  4.5  4.5  9.65       1.0      1
# 1    324.0    107          4.0  4.0  4.5  8.87       1.0      1
# 2    316.0    104          3.0  3.0  3.5  8.00       1.0      1
# 3    322.0    110          3.0  3.5  2.5  8.67       1.0      1
# 4    314.0    103          2.0  2.0  3.0  8.21       0.0      0
# 5    330.0    115          5.0  4.5  3.0  9.34       1.0      1
# 6    330.0    109          3.0  3.0  4.0  8.20       1.0      1
# 7    308.0    101          2.0  3.0  4.0  7.90       0.0      0
# 8    302.0    102          2.0  2.0  1.5  8.00       0.0      0
# 9    323.0    108          3.0  3.5  3.0  8.60       0.0      0
# 10   325.0    106          3.0  3.5  4.0  8.40       1.0      0
# 11   325.0    111          4.0  4.0  4.5  9.00       1.0      0
# 12   328.0    112          4.0  4.0  4.5  9.10       1.0      1
# 13   307.0    109          3.0  4.0  3.0  8.00       1.0      0
# ...

# %%
df6=df1.fillna(method='bfill')

# %%
df6
# Out:
#        GRE  TOEFL  Univ_Rating  SOP  LOR  CGPA  Research  Admit
# 0    337.0    118          4.0  4.5  4.5  9.65       1.0      1
# 1    324.0    107          4.0  4.0  4.5  8.87       1.0      1
# 2    316.0    104          3.0  3.0  3.5  8.00       1.0      1
# 3    322.0    110          2.0  3.5  2.5  8.67       1.0      1
# 4    314.0    103          2.0  2.0  3.0  8.21       0.0      0
# 5    330.0    115          5.0  4.5  3.0  9.34       1.0      1
# 6    308.0    109          3.0  3.0  4.0  8.20       1.0      1
# 7    308.0    101          2.0  3.0  4.0  7.90       0.0      0
# 8    302.0    102          3.0  2.0  1.5  8.00       0.0      0
# 9    323.0    108          3.0  3.5  3.0  8.60       0.0      0
# 10   325.0    106          3.0  3.5  4.0  8.40       1.0      0
# 11   328.0    111          4.0  4.0  4.5  9.00       1.0      0
# 12   328.0    112          4.0  4.0  4.5  9.10       1.0      1
# 13   307.0    109          3.0  4.0  3.0  8.00       1.0      0
# ...

# %%
df7=df1.interpolate()

# %%
df7
# Out:
#             GRE  TOEFL  Univ_Rating   SOP  LOR   CGPA  Research  Admit
# 0    337.000000    118          4.0  4.50  4.5  9.650       1.0      1
# 1    324.000000    107          4.0  4.00  4.5  8.870       1.0      1
# 2    316.000000    104          3.0  3.00  3.5  8.000       1.0      1
# 3    322.000000    110          2.5  3.50  2.5  8.670       1.0      1
# 4    314.000000    103          2.0  2.00  3.0  8.210       0.0      0
# 5    330.000000    115          5.0  4.50  3.0  9.340       1.0      1
# 6    319.000000    109          3.0  3.00  4.0  8.200       1.0      1
# 7    308.000000    101          2.0  3.00  4.0  7.900       0.0      0
# 8    302.000000    102          2.5  2.00  1.5  8.000       0.0      0
# 9    323.000000    108          3.0  3.50  3.0  8.600       0.0      0
# 10   325.000000    106          3.0  3.50  4.0  8.400       1.0      0
# 11   326.500000    111          4.0  4.00  4.5  9.000       1.0      0
# ...

# %%
df9=df1

# %%
df.GRE.mean()
# Out:
# 316.8075

# %%
GRE=[df9['GRE'].fillna(316.8)]

# %%
GRE
# Out:
#        GRE
# 0    337.0
# 1    324.0
# 2    316.0
# 3    322.0
# 4    314.0
# 5    330.0
# 6    316.8
# 7    308.0
# 8    302.0
# 9    323.0
# 10   325.0
# 11   316.8
# 12   328.0
# 13   307.0
# 14   311.0
# 15   314.0
# 16   317.0
# 17   319.0
# 18   316.8
# 19   316.8
# 20   312.0
# 21   325.0
# 22   328.0
# 23   334.0
# 24   336.0
# 25   340.0
# 26   322.0
# 27   298.0
# 28   295.0
# 29   310.0
# 30   300.0
# 31   327.0
# 32   338.0
# 33   340.0
# 34   331.0
# 35   320.0
# 36   299.0
# 37   300.0
# 38   304.0
# 39   307.0
# 40   308.0
# 41   316.0
# 42   313.0
# 43   332.0
# 44   326.0
# 45   322.0
# 46   329.0
# 47   339.0
# 48   321.0
# 49   327.0
# 50   313.0
# 51   312.0
# 52   334.0
# 53   324.0
# 54   322.0
# 55   320.0
# 56   316.0
# 57   298.0
# 58   300.0
# 59   311.0
# 60   309.0
# 61   307.0
# 62   304.0
# 63   315.0
# 64   325.0
# 65   325.0
# 66   327.0
# 67   316.0
# 68   318.0
# 69   328.0
# 70   332.0
# 71   336.0
# 72   321.0
# 73   314.0
# 74   314.0
# ...
