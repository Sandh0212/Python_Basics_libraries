# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\kamal'

# %%
p="E:\Python"

# %%
os.chdir(p)

# %%
os.getcwd()
# Out:
# 'E:\\Python'

# %%
import pandas as pd

# %%
df=pd.read_csv('admit_missing.csv')

# %%
df=pd.read_csv('admit_missing.csv')

# %%
df
# Out:
#        GRE  TOEFL  Univ_Rating  SOP  LOR  CGPA  Research  Admit
# 0    337.0    118          4.0  4.5  4.5  9.65       1.0      1
# 1    324.0    107          4.0  4.0  4.5  8.87       1.0      1
# 2    316.0    104          3.0  3.0  3.5  8.00       1.0      1
# 3    322.0    110          NaN  3.5  2.5  8.67       1.0      1
# 4    314.0    103          2.0  2.0  3.0  8.21       0.0      0
# ..     ...    ...          ...  ...  ...   ...       ...    ...
# 395  324.0    110          3.0  3.5  3.5  9.04       1.0      1
# 396  325.0    107          3.0  3.0  3.5  9.11       1.0      1
# 397  330.0    116          4.0  5.0  4.5  9.45       1.0      1
# 398  312.0    103          3.0  3.5  4.0  8.78       0.0      0
# 399  333.0    117          4.0  5.0  4.0  9.66       1.0      1
#
# [400 rows x 8 columns]

# %%
df1=pd.read_csv('admit.csv')

# %%
df1
# Out:
#      GRE  TOEFL  Univ_Rating  SOP  LOR  CGPA  Research  Admit
# 0    337    118            4  4.5  4.5  9.65         1      1
# 1    324    107            4  4.0  4.5  8.87         1      1
# 2    316    104            3  3.0  3.5  8.00         1      1
# 3    322    110            3  3.5  2.5  8.67         1      1
# 4    314    103            2  2.0  3.0  8.21         0      0
# ..   ...    ...          ...  ...  ...   ...       ...    ...
# 395  324    110            3  3.5  3.5  9.04         1      1
# 396  325    107            3  3.0  3.5  9.11         1      1
# 397  330    116            4  5.0  4.5  9.45         1      1
# 398  312    103            3  3.5  4.0  8.78         0      0
# 399  333    117            4  5.0  4.0  9.66         1      1
#
# [400 rows x 8 columns]

# %%
pd.set_option('display.max_rows',500)

# %%
df1
# Out:
#      GRE  TOEFL  Univ_Rating  SOP  LOR  CGPA  Research  Admit
# 0    337    118            4  4.5  4.5  9.65         1      1
# 1    324    107            4  4.0  4.5  8.87         1      1
# 2    316    104            3  3.0  3.5  8.00         1      1
# 3    322    110            3  3.5  2.5  8.67         1      1
# 4    314    103            2  2.0  3.0  8.21         0      0
# 5    330    115            5  4.5  3.0  9.34         1      1
# 6    321    109            3  3.0  4.0  8.20         1      1
# 7    308    101            2  3.0  4.0  7.90         0      0
# 8    302    102            1  2.0  1.5  8.00         0      0
# 9    323    108            3  3.5  3.0  8.60         0      0
# 10   325    106            3  3.5  4.0  8.40         1      0
# 11   327    111            4  4.0  4.5  9.00         1      1
# 12   328    112            4  4.0  4.5  9.10         1      1
# 13   307    109            3  4.0  3.0  8.00         1      0
# ...

# %%
pd.set_option('display.max_columns',10)

# %%
df1
# Out:
#      GRE  TOEFL  Univ_Rating  SOP  LOR  CGPA  Research  Admit
# 0    337    118            4  4.5  4.5  9.65         1      1
# 1    324    107            4  4.0  4.5  8.87         1      1
# 2    316    104            3  3.0  3.5  8.00         1      1
# 3    322    110            3  3.5  2.5  8.67         1      1
# 4    314    103            2  2.0  3.0  8.21         0      0
# 5    330    115            5  4.5  3.0  9.34         1      1
# 6    321    109            3  3.0  4.0  8.20         1      1
# 7    308    101            2  3.0  4.0  7.90         0      0
# 8    302    102            1  2.0  1.5  8.00         0      0
# 9    323    108            3  3.5  3.0  8.60         0      0
# 10   325    106            3  3.5  4.0  8.40         1      0
# 11   327    111            4  4.0  4.5  9.00         1      1
# 12   328    112            4  4.0  4.5  9.10         1      1
# 13   307    109            3  4.0  3.0  8.00         1      0
# ...

# %%
                                                                                                                                                                                                                                                                                                                                                                    type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
print(type(df1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.head(20)
# Out:
#       GRE  TOEFL  Univ_Rating  SOP  LOR  CGPA  Research  Admit
# 0   337.0    118          4.0  4.5  4.5  9.65       1.0      1
# 1   324.0    107          4.0  4.0  4.5  8.87       1.0      1
# 2   316.0    104          3.0  3.0  3.5  8.00       1.0      1
# 3   322.0    110          NaN  3.5  2.5  8.67       1.0      1
# 4   314.0    103          2.0  2.0  3.0  8.21       0.0      0
# 5   330.0    115          5.0  4.5  3.0  9.34       1.0      1
# 6     NaN    109          3.0  3.0  4.0  8.20       1.0      1
# 7   308.0    101          2.0  3.0  4.0  7.90       0.0      0
# 8   302.0    102          NaN  2.0  1.5  8.00       NaN      0
# 9   323.0    108          3.0  3.5  3.0  8.60       0.0      0
# 10  325.0    106          3.0  3.5  4.0  8.40       1.0      0
# 11    NaN    111          4.0  4.0  4.5  9.00       1.0      0
# 12  328.0    112          4.0  4.0  4.5  9.10       1.0      1
# 13  307.0    109          3.0  4.0  3.0  8.00       1.0      0
# ...

# %%
df.tail(20)
# Out:
#        GRE  TOEFL  Univ_Rating  SOP  LOR  CGPA  Research  Admit
# 380  322.0    104          3.0  3.5  4.0  8.84       1.0      1
# 381  319.0    105          3.0  3.0  3.5  8.67       1.0      1
# 382  324.0    110          4.0  4.5  4.0  9.15       1.0      1
# 383  300.0    100          3.0  3.0  3.5  8.26       0.0      0
# 384  340.0    113          4.0  5.0  5.0  9.74       1.0      1
# 385  335.0    117          5.0  5.0  5.0  9.82       1.0      1
# 386  302.0    101          2.0  2.5  3.5  7.96       0.0      0
# 387  307.0    105          2.0  2.0  3.5  8.10       0.0      0
# 388  296.0     97          2.0  1.5  2.0  7.80       0.0      0
# 389  320.0    108          3.0  3.5  4.0  8.44       1.0      1
# 390  314.0    102          2.0  2.0  2.5  8.24       0.0      0
# 391  318.0    106          3.0  2.0  3.0  8.65       0.0      1
# 392  326.0    112          4.0  4.0  3.5  9.12       1.0      1
# 393  317.0    104          2.0  3.0  3.0  8.76       0.0      1
# ...

# %%
df.shape
# Out:
# (400, 8)

# %%
df.describe()
# Out:
#               GRE       TOEFL  Univ_Rating         SOP         LOR  \
# count  396.000000  400.000000   394.000000  395.000000  400.000000
# mean   316.803030  107.410000     3.078680    3.388608    3.452500
# std     11.497125    6.069514     1.135323    1.005819    0.898478
# min    290.000000   92.000000     1.000000    1.000000    1.000000
# 25%    308.000000  103.000000     2.000000    2.500000    3.000000
# 50%    317.000000  107.000000     3.000000    3.500000    3.500000
# 75%    325.000000  112.000000     4.000000    4.000000    4.000000
# max    340.000000  120.000000     5.000000    5.000000    5.000000
#
#              CGPA    Research       Admit
# count  391.000000  399.000000  400.000000
# mean     8.598338    0.548872    0.585000
# std      0.595744    0.498231    0.493339
# min      6.800000    0.000000    0.000000
# 25%      8.170000    0.000000    0.000000
# 50%      8.600000    1.000000    1.000000
# 75%      9.060000    1.000000    1.000000
# ...

# %%
df['CGPA'].mean()
# Out:
# 8.598337595907928

# %%
df['TOEFL'].count()
# Out:
# 400

# %%
df['SOP'].std()
# Out:
# 1.005819026542733

# %%
df['LOR'].min()
# Out:
# 1.0

# %%
df['LOR'].max()
# Out:
# 5.0

# %%
df['Admit'].quantile(0.25)
# Out:
# 0.0

# %%
df['Admit'].quantile(0.50)
# Out:
# 1.0

# %%
df['Admit'].quantile(0.75)
# Out:
# 1.0

# %%
df.shape[1]
# Out:
# 8

# %%
a=[1,2,3,4,5,6,7,8,9]

# %%
import numpy as np

# %%
a1=np.array(a)

# %%
a1.mean()
# Out:
# 5.0
